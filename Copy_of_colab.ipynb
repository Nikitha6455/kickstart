# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikitha6455/kickstart/blob/main/Copy_of_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 1: Hardcoding Variables

name = "Alice"
age = 20
cgpa = 8.5

print("Name:", name)
print("Age:", age)
print("CGPA:", cgpa)
# Out:
# Name: Alice
# Age: 20
# CGPA: 8.5

# %%
# Program 2: Keyboard Input

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name)
print("Your age is", age)
# Out:
# Enter your name: nikitha
# Enter your age: 19
# Hello nikitha
# Your age is 19

# %%
# Program 5: Debugging Example

try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    print("Result:", a / b)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter valid integers.")
# Out:
# Enter a number: 9
# Enter another number: 3
# Result: 3.0

# %% [markdown]
# 4

# %%
a = 10
b = 20
print("Sum:", a + b)
# Out:
# Sum: 30

# %% [markdown]
# 5

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Maximum is:", max(a, b))
# Out:
# Enter first number: 20
# Enter second number: 35
# Maximum is: 35

# %%
6

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 4
# Even number

# %% [markdown]
# 7

# %%
p = float(input("Enter principal: "))
r = float(input("Enter rate: "))
t = float(input("Enter time: "))

si = (p * r * t) / 100
print("Simple Interest:", si)
# Out:
# Enter principal: 5000
# Enter rate: 2500
# Enter time: 5
# Simple Interest: 625000.0

# %% [markdown]
# 8

# %%
with open("name.txt", "w") as f:
    f.write("John")

with open("name.txt", "r") as f:
    name = f.read()

print("Name from file:", name)
# Out:
# Name from file: John

# %% [markdown]
# 9

# %%
with open("lines.txt", "w") as f:
    f.write("One\nTwo\nThree")

with open("lines.txt", "r") as f:
    lines = f.readlines()

print("Number of lines:", len(lines))
# Out:
# Number of lines: 3

# %% [markdown]
# 10

# %%
n = int(input("Enter a number: "))
fact = 1

for i in range(1, n + 1):
    fact *= i

print("Factorial:", fact)
# Out:
# Enter a number: 3
# Factorial: 6

# %% [markdown]
# 11

# %%
text = input("Enter a string: ")
print("Reversed:", text[::-1])
# Out:
# Enter a string: computer
# Reversed: retupmoc

# %% [markdown]
# 12

# %%
numbers = [1, 2, 3, 4, 5]
print("Sum:", sum(numbers))
# Out:
# Sum: 15

# %% [markdown]
# 13

# %%
with open("avg.txt", "w") as f:
    f.write("10\n20\n30")

with open("avg.txt", "r") as f:
    nums = [int(x) for x in f]

avg = sum(nums) / len(nums)
print("Average:", avg)
# Out:
# Average: 20.0

# %% [markdown]
# 14

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a, b = b, a

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 3
# Enter second number: 6
# After swapping:
# a = 6
# b = 3

# %% [markdown]
# 15

# %%
num = input("Enter a number: ")
print("Number of digits:", len(num))
# Out:
# Enter a number: 50
# Number of digits: 2
